# %%
import dash
import dash_html_components as html
import dash_core_components as dcc 
from dash.dependencies import Input, Output

import numpy as np
import pandas as pd

import plotly.express as px  # (version 4.7.0 or higher)
import plotly.graph_objects as go
import seaborn as sns
import matplotlib as plt
import datetime
from dateutil.relativedelta import relativedelta   
import warnings
warnings.filterwarnings('ignore')
# Out:
# c:\Users\holol\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
print(
    'you can open it with google Drive',
    '\n','i hope you\'ve learn alot '
    '\n','could you tell me what is your real','\n',
    ' '.join('mohammed is a good man for his brothers'),'\n',
    '{}@{}.com'.format('momame','gmail')
    )
df = sns.load_dataset('titanic')
df
# Out:
# you can open it with google Drive
#  i hope you've learn alot
#  could you tell me what is your real
#  m o h a m m e d   i s   a   g o o d   m a n   f o r   h i s   b r o t h e r s
#  momame@gmail.com
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
print(
    'the columns of the data is: \n',df.columns,'\n \n',
    'the shape of the date is: \n',df.shape,'\n',
    'champuan do not lesten to the negteve people \n',
    'the summ of null in the data in each column: \n', df.isna().sum()
)
# Out:
# the columns of the data is:
#  Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')
#
#  the shape of the date is:
#  (891, 15)
#  champuan do not lesten to the negteve people
#  the summ of null in the data in each column:
#  survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
fig = px.bar(data_frame=df,x='embark_town',template='plotly_dark',width=700)
fig.show()
fig = px.bar(data_frame=df,x='who',template='plotly_dark',width=700)
fig.show()
fig = px.bar(data_frame=df,x='alive',template='plotly_dark',width=700)
fig.show()
fig = px.bar(data_frame=df,x='class',template='plotly_dark',width=700)
fig.show()
fig = px.bar(data_frame=df,x='age',template='plotly_dark',width=700)
fig.show()

# %%
app = dash.Dash(__name__)

#-----------------------------------------
app.layout = html.Div([
    html.Div([
        html.Label(['Explorty analysis for titanic Dataset']),
        dcc.Dropdown(
            id='my_dropdown',
            options=[
                      {'label': 'sex','value':'sex'},
                      {'label': 'age','value':'age'},
                      {'label': 'who','value':'who'},
                      {'label': 'class','value':'class'},
                      {'label': 'embark_town','value':'embark_town'}
                      
            ],
            value='who',
            multi=False,
            clearable=False,
            style={'width':'80%'}
        ),
    ]),
    html.Div([
        dcc.Graph(id='the_graph')
    ]),
])

#-----------------------------------------------------------------
@app.callback(
    Output(component_id='the_graph',component_property='figure'),
    [Input(component_id= 'my_dropdown', component_property='value')]
)

def update_graph(my_dropdown):
    dff = df

    piechart = px.pie(
                data_frame=dff,
                names=my_dropdown,
                hole=.3,
                template='plotly_dark'
    )
    return (piechart)

#-------------------------------------------
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [09/Sep/2022 10:31:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2022 10:31:56] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2022 10:31:56] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2022 10:31:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2022 10:32:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2022 10:32:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2022 10:32:12] "POST /_dash-update-component HTTP/1.1" 200 -
# ...

# %%
import webbrowser as web
web.open('http://127.0.0.1:8050/')
# Out:
# True

# %% [markdown]
# ___

# %%
csv_file = 'Urban_Park_Ranger_Animal_Condition_Response.csv'
data = pd.read_csv(csv_file)
print(
    'the shape of data is:\n',data.shape,'\n-------\n',
    'the columns of the data is: ',data.columns,'\n-------\n',
    'the null values: \n',data.isna().sum(),'\n-------\n'
)

data.head(3)
# Out:
# the shape of data is:
#  (982, 22)
# -------
#  the columns of the data is:  Index(['Date and Time of initial call', 'Date and time of Ranger response',
#        'Borough', 'Property', 'Location', 'Species Description', 'Call Source',
#        'Species Status', 'Animal Condition', 'Duration of Response', 'Age',
#        'Animal Class', '311SR Number', 'Final Ranger Action', '# of Animals',
#        'PEP Response', 'Animal Monitored', 'Rehabilitator',
#        'Hours spent monitoring', 'Police Response', 'ESU Response',
#        'ACC Intake Number'],
#       dtype='object')
# -------
#  the null values:
#  Date and Time of initial call         0
# Date and time of Ranger response      0
# Borough                               0
# Property                              0
# Location                             62
# Species Description                   4
# Call Source                           0
# Species Status                        0
# Animal Condition                      0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 982 entries, 0 to 981
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Date and Time of initial call     982 non-null    object
#  1   Date and time of Ranger response  982 non-null    object
#  2   Borough                           982 non-null    object
#  3   Property                          982 non-null    object
#  4   Location                          920 non-null    object
#  5   Species Description               978 non-null    object
#  6   Call Source                       982 non-null    object
#  7   Species Status                    982 non-null    object
#  8   Animal Condition                  982 non-null    object
#  9   Duration of Response              982 non-null    float64
#  10  Age                               982 non-null    object
# ...

# %%
data.describe()
# Out:
#        Duration of Response  # of Animals  Hours spent monitoring
# count            982.000000    974.000000              120.000000
# mean               1.389868      1.090349                0.966667
# std                1.135502      0.732486                0.847818
# min                0.000000      0.000000                0.150000
# 25%                0.750000      1.000000                0.500000
# 50%                1.000000      1.000000                0.500000
# 75%                2.000000      1.000000                1.000000
# max               21.000000     11.000000                4.000000

# %%
app = dash.Dash(__name__)

#-----------------------------------------
app.layout = html.Div([
    html.Div([
        html.Label(['NYC Calls for animal Rescue']),
        dcc.Dropdown(
            id='my_dropdown',
            options=[
                      {'label': 'Action Taken by Ranger','value':'Final Ranger Action'},
                      {'label': 'Age','value':'Age'},
                      {'label': 'Animal Health','value':'Animal Condition'},
                      {'label': 'Species','value':'Animal Class'},
                      {'label': 'Borough','value':'Borough'},
                      {'label': 'Species Status','value':'Species Status'}
                      
            ],
            value='Animal Class',
            multi=False,
            clearable=False,
            style={'width':'50%'}
        ),
    ]),
    html.Div([
        dcc.Graph(id='the_graph')
    ]),
])

#-----------------------------------------------------------------
@app.callback(
    Output(component_id='the_graph',component_property='figure'),
    [Input(component_id= 'my_dropdown', component_property='value')]
)

def update_graph(my_dropdown):
    dataa = data

    piechart = px.pie(
                data_frame=dataa,
                names=my_dropdown,
                hole=.3,
                template='plotly_dark'
    )
    return (piechart)

#-------------------------------------------
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [09/Sep/2022 10:35:36] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2022 10:35:39] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2022 10:35:39] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2022 10:35:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2022 10:35:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2022 10:35:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2022 10:35:47] "POST /_dash-update-component HTTP/1.1" 200 -
# ...
